# %% [markdown]
# <a href="https://colab.research.google.com/github/kyunghyunHan/-Algorithm/blob/main/src/pytoch/pytoch01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import torch

a= torch.tensor([1,2,3])
b= torch.tensor([4,5,6])
c= a+b
print(c)
# Out:
# tensor([5, 7, 9])

# %%
# 파이토치의 신경망의 기본구성
class Net(torch.nn.Module):
    def __init__(self):
    # 신경망의 구성요소 정의


     def forward(self,input):
    #신경망의동작정의
      return output

# %%
class Dataset():
  def __init__(self):## 학습에 사용할 데이터 불로오기


   def __len__(self):#데이터 개수반환
    return len(data)

  def __getitem__(self,i): #i번쨰 입력데이터와 정답을 반환
    return data[i],label[i]

# %%
#데이터로부터 데이터와 정답을 받아옴
for data,label in DataLoader():
    prediction = model(data)

  #손실함수를 이용 오차계산

    loss= LossFunction(prediction,label)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-0eb95173f0b7> in <cell line: 2>()
#       1 #데이터로부터 데이터와 정답을 받아옴
# ----> 2 for data,label in DataLoader():
#       3   prediction = model(data)
#       4
#       5   #손실함수를 이용 오차계산
#
# NameError: name 'DataLoader' is not defined
